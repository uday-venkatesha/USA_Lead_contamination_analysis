# %%
install.packages("ggplot2")
library(ggplot2)
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
install.packages("caret")
library(caret)
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘listenv’, ‘parallelly’, ‘future’, ‘globals’, ‘shape’, ‘future.apply’, ‘numDeriv’, ‘progressr’, ‘SQUAREM’, ‘diagram’, ‘lava’, ‘prodlim’, ‘proxy’, ‘iterators’, ‘Rcpp’, ‘clock’, ‘gower’, ‘hardhat’, ‘ipred’, ‘timeDate’, ‘e1071’, ‘foreach’, ‘ModelMetrics’, ‘plyr’, ‘pROC’, ‘recipes’, ‘reshape2’
#
#
# Loading required package: lattice

# %%
install.packages("data.table")
library(data.table)
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
data <- read.csv("/content/NJ1.csv")
head(data)
# Out:
#   County.    Total_children PercentageScreened BLL_LT_5 BLL_5to9 BLL_10to14
# 1 ATLANTIC    52860         21                 10791    210      35
# 2 BERGEN     162294         25                 39571    373      82
# 3 BURLINGTON  83424         18                 14588    209      38
# 4 CAMDEN     106820         19                 19641    294      43
# 5 CAPE MAY    14490         18                  2590     32       8
# 6 CUMBERLAND  34662         25                  8290    276      44
#   BLL_15to19 BLL_20to44 BLL_above45 Total_EBLL Total_Screened PercentageEBLL
# 1 11          6         1           163        11055          1.47
# 2 18         19         1           331        40070          0.83
# 3  8         14         1           196        14859          1.32
# 4 13         16         0           250        20010          1.25
# 5  3          2         0            32         2635          1.21
# 6 12          7         1           238         8629          2.76
#   Income
# 1 39902
# 2 69199
# 3 49930
# 4 43645
# 5 49971
# 6 36569

# %%
colnames(data)
# Out:
#  [1] "County."            "Total_children"     "PercentageScreened"
#  [4] "BLL_LT_5"           "BLL_5to9"           "BLL_10to14"
#  [7] "BLL_15to19"         "BLL_20to44"         "BLL_above45"
# [10] "Total_EBLL"         "Total_Screened"     "PercentageEBLL"
# [13] "Income"

# %%
str(data)
# Out:
# 'data.frame':	20 obs. of  13 variables:
#  $ County.           : chr  "ATLANTIC" "BERGEN" "BURLINGTON" "CAMDEN" ...
#  $ Total_children    : int  52860 162294 83424 106820 14490 34662 172320 55842 134094 19600 ...
#  $ PercentageScreened: int  21 25 18 19 18 25 39 14 36 22 ...
#  $ BLL_LT_5          : int  10791 39571 14588 19641 2590 8290 64795 7599 47246 4163 ...
#  $ BLL_5to9          : int  210 373 209 294 32 276 2203 90 922 53 ...
#  $ BLL_10to14        : int  35 82 38 43 8 44 356 14 191 15 ...
#  $ BLL_15to19        : int  11 18 8 13 3 12 105 5 58 5 ...
#  $ BLL_20to44        : int  6 19 14 16 2 7 103 2 60 5 ...
#  $ BLL_above45       : int  1 1 1 0 0 1 12 0 2 0 ...
#  $ Total_EBLL        : int  163 331 196 250 32 238 1811 78 838 66 ...
#  $ Total_Screened    : int  11055 40070 14859 20010 2635 8629 67582 7710 48485 4241 ...
#  $ PercentageEBLL    : num  1.47 0.83 1.32 1.25 1.21 2.76 2.68 1.01 1.73 1.56 ...
#  $ Income            : int  39902 69199 49930 43645 49971 36569 47867 44358 52623 71828 ...

# %%
data$Income<- as.numeric(data$Income)

# %%
install.packages("corrplot")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
hist(data$Income)
# Out:
# Plot with title “Histogram of data$Income”

# %%
ggplot(data, aes(x = County., y = PercentageScreened)) +
  geom_bar(stat = "identity", fill = "lightblue") +
  theme_minimal() +
  labs(title = "Total Children Screened by County",
       x = "County",
       y = "Percent Screened")
# Out:
# plot without title

# %%
library(ggplot2)

ggplot(data, aes(x = Income, y = PercentageScreened)) +
  geom_point(color = "#4e79a7", size = 3, alpha = 0.7) +
  labs(
    x = "Per Capita Income",
    y = "% of People Affected",
    title = "Relationship Between Income and % of People Affected",
    fill = "Variable Legend"  # Corrected from color to fill
  ) +
  theme_minimal() +
  theme(
    plot.title = element_text(size = 16, face = "bold", hjust = 0.5),
    axis.title = element_text(size = 14),
    axis.text = element_text(size = 12),
    legend.position = "bottom"
  )
# Out:
# plot without title

# %%
# Example: Larger bar chart with vertical county names
ggplot(data, aes(x = County., y = PercentageScreened)) +
  geom_bar(fill = "#4e79a7", alpha = 0.7, stat = "identity") +
  labs(
    x = "County",
    y = "% People Affected",
    title = " % People Affected by each County",
    fill = "Legend Title"
  ) +
  theme_minimal() +
  theme(
    axis.text.x = element_text(angle = 90, vjust = 0.5, hjust = 1),  # Rotate and adjust county names
    plot.title = element_text(size = 16, face = "bold", hjust = 0.5),  # Increase title size
    axis.title = element_text(size = 14),  # Increase axis label size
    axis.text = element_text(size = 12),  # Increase axis text size
    legend.position = "bottom",  # Change legend position
    plot.margin = margin(1, 1, 2, 1, "cm")  # Adjust margins for a larger plot
  )
# Out:
# plot without title

# %%
library(ggplot2)

# Assuming 'Income' is a categorical variable
ggplot(data, aes(x = County., y = PercentageScreened, fill = Income)) +
  geom_bar(alpha = 0.7, stat = "identity") +
  labs(
    x = "County",
    y = "% People Affected",
    title = "Comparison of Per Capita Income and % People Affected",

  ) +
  theme_minimal() +
  theme(
    axis.text.x = element_text(angle = 90, vjust = 0.5, hjust = 1),
    plot.title = element_text(size = 16, face = "bold", hjust = 0.5),
    axis.title = element_text(size = 14),
    axis.text = element_text(size = 12),
    legend.position = "bottom",
    plot.margin = margin(1, 1, 2, 1, "cm")
  )
# Out:
# plot without title

# %%
ggplot(data,aes(x=Income,y=PercentageScreened),group=1)+
  geom_line(aes(y=PercentageScreened),color= "Green", size=2)+
  theme_minimal()+

  theme( axis.text.x = element_text(angle = 90, vjust = 0.5, hjust = 1),
      plot.title = element_text(size = 16, face = "bold", hjust = 0.5),
      axis.title = element_text(size = 14),
      axis.text = element_text(size = 12),
      plot.margin = margin(1, 1, 2, 1, "cm"))
# Out:
# Warning message:
# “Using `size` aesthetic for lines was deprecated in ggplot2 3.4.0.
# ℹ Please use `linewidth` instead.”
# plot without title

# %%
numeric_data <- data[, sapply(data, is.numeric)]
pairs(numeric_data, cex = 1 )
# Out:
# plot without title

# %%
corelation_matrix <- cor(numeric_data)
print(corelation_matrix)
corrplot(corelation_matrix)
# Out:
#                    Total_children PercentageScreened    BLL_LT_5   BLL_5to9
# Total_children         1.00000000          0.6266446  0.92125214  0.6681797
# PercentageScreened     0.62664456          1.0000000  0.85020635  0.8149917
# BLL_LT_5               0.92125214          0.8502063  1.00000000  0.8514824
# BLL_5to9               0.66817972          0.8149917  0.85148243  1.0000000
# BLL_10to14             0.69799296          0.8181935  0.87370357  0.9895779
# BLL_15to19             0.70048415          0.7971326  0.85863858  0.9645783
# BLL_20to44             0.69511041          0.8053194  0.85758757  0.9541264
# BLL_above45            0.61036392          0.6330531  0.75364727  0.9233552
# Total_EBLL             0.68439085          0.8186018  0.86079892  0.9973323
# Total_Screened         0.91707706          0.8531762  0.99983500  0.8608483
# PercentageEBLL        -0.12821266          0.3233269  0.06200035  0.3906461
# Income                 0.07321768         -0.1140952 -0.04014909 -0.1699937
#                    BLL_10to14 BLL_15to19  BLL_20to44 BLL_above45 Total_EBLL
# Total_children      0.6979930  0.7004842  0.69511041   0.6103639  0.6843909
# PercentageScreened  0.8181935  0.7971326  0.80531941   0.6330531  0.8186018
# BLL_LT_5            0.8737036  0.8586386  0.85758757   0.7536473  0.8607989
# BLL_5to9            0.9895779  0.9645783  0.95412645   0.9233552  0.9973323
# BLL_10to14          1.0000000  0.9758294  0.96963650   0.9075654  0.9945123
# BLL_15to19          0.9758294  1.0000000  0.96448052   0.8766858  0.9773163
# BLL_20to44          0.9696365  0.9644805  1.00000000   0.8384005  0.9703404
# BLL_above45         0.9075654  0.8766858  0.83840046   1.0000000  0.9129777
# Total_EBLL          0.9945123  0.9773163  0.97034036   0.9129777  1.0000000
# Total_Screened      0.8821846  0.8667881  0.86545501   0.7631794  0.8698703
# PercentageEBLL      0.3634957  0.3649950  0.34993602   0.2947284  0.3858056
# Income             -0.1221109 -0.1167674 -0.08962863  -0.1344804 -0.1494612
#                    Total_Screened PercentageEBLL      Income
# Total_children         0.91707706    -0.12821266  0.07321768
# PercentageScreened     0.85317619     0.32332685 -0.11409521
# BLL_LT_5               0.99983500     0.06200035 -0.04014909
# BLL_5to9               0.86084830     0.39064615 -0.16999368
# BLL_10to14             0.88218463     0.36349574 -0.12211089
# BLL_15to19             0.86678806     0.36499500 -0.11676738
# BLL_20to44             0.86545501     0.34993602 -0.08962863
# BLL_above45            0.76317936     0.29472836 -0.13448040
# Total_EBLL             0.86987029     0.38580556 -0.14946123
# Total_Screened         1.00000000     0.07376611 -0.04454941
# PercentageEBLL         0.07376611     1.00000000 -0.37094619
# Income                -0.04454941    -0.37094619  1.00000000
# Error in corrplot(corelation_matrix): could not find function "corrplot"
# Traceback:

# %% [markdown]
# Income and %EBLL have 40% corelation.
#
# Higher the income the % of people having EBLL decreases . Which means people having higher income is taking measures to avoid BLL and are keeping it less than 5.

# %%
ggplot(data, aes(x=Income,y=PercentageEBLL))+
  geom_point()+
    geom_smooth(method = "lm", se = FALSE, color = "blue") +
    labs(title = "Scatter Plot of EBLL vs. Income",
        x = "Income",
        y = "EBLL")
